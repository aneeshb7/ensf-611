# %% [markdown]
# # Visualization
#
# Using the heart-attack.csv example below, fill in the code blocks for a new dataset, auto-mpg
#
# The first step is to download the auto-mpg data set (auto-mpg.data and auto-mpg.names) from UCI: https://archive.ics.uci.edu/ml/datasets/Auto%2BMPG
#
# In this file, replace gender with origin and age with mpg

# %% [markdown]
# ## Resources
# 1. Ch 9 in Python for Data Analysis, 2nd Ed, Wes McKinney (UCalgary library and https://github.com/wesm/pydata-book)
# 2. Ch 4 in Python Data Science Handbook, Jake VanderPlas (Ucalgary library and https://github.com/jakevdp/PythonDataScienceHandbook)
# 3. Fundamentals of Data Visualization, Claus O. Wilke (Ucalgary library and https://serialmentor.com/dataviz/index.html)
# 4. Overview by Jake VanderPlas https://www.youtube.com/watch?v=FytuB8nFHPQ

# %% [markdown]
# ## Matplotlib
# > Matplotlib is a Python 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.
# Matplotlib tries to make easy things easy and hard things possible.
# For simple plotting the pyplot module provides a MATLAB-like interface
#
# https://matplotlib.org
#
# Importing matplotlib looks like this

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Two interfaces
# There are two ways to interact with Matplot lib: a Matlab style and an object oriented style interface.
#
# See Ch 4 in Python Data Science Handbook, Jake VanderPlas
#
# - Two Interfaces for the Price of One, pp. 222
# - Matplotlib Gotchas, pp. 232

# %% [markdown]
# ## Plotting with pandas
# > We use the standard convention for referencing the matplotlib API ...
# > We provide the basics in pandas to easily create decent looking plots.
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
#
# Let's load the required dataset:

# %%
# Replace code below with code to load auto-mpg dataset
# Hint: Use attribute information from website to determine column names
# Hint: Load with na_values = '?' and sep=r'\s+'
data = pd.read_csv('auto-mpg.data', na_values='?', sep=r'\s+', header=None,
                   names=['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name'])

# %% [markdown]
# Plotting all columns, works, but does not provide a lot of insight.

# %%
data.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Let's look at one distribution (a histogram)

# %%
# Replace variables to correspond to auto-mpg dataset
data['mpg'].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %% [markdown]
# How many samples do we have for each origin?

# %%
# Replace variables to correspond to auto-mpg dataset
data.origin.value_counts()
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %% [markdown]
#   Plotting multiple histograms directly from the dataframe:

# %%
# Replace variables to correspond to auto-mpg dataset
axs = data.hist(column='mpg', by='origin')

# %% [markdown]
# To format this plot, we can work on the axes (array) that is returned by the plot call. We use Matplotlib object oriented interface methods to do this

# %%
# Replace variables to correspond to auto-mpg dataset
# Hint: may need to use .flatten()
axs = data.hist(column='mpg', by='origin').flatten()
axs[0].set(title='mpg', ylim=[0, 45])
axs[1].set(title='origin', ylim=[0, 45])
# Out:
# [Text(0.5, 1.0, 'origin'), (0.0, 45.0)]

# %% [markdown]
# Are mpg and weight correlated? Maybe it is for different origins?
# Let's have a look with a scatter plot.

# %%
# Replace variables to correspond to auto-mpg dataset
data.plot.scatter('mpg', 'weight', c='origin')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Replace variables to correspond to auto-mpg dataset
# ----> 2 data.plot.scatter('mpg', 'weight', c='origin', colormap='viridis')
#
# File c:\Python39\lib\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
#    1667 ) -> PlotAccessor:
#    1668     """
#    1669     Create a scatter plot with varying marker point size and color.
#    1670
#    (...)
#    1746         ...                       colormap='viridis')
#    1747     """
# -> 1748     return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#
# File c:\Python39\lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File c:\Python39\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1338, in ScatterPlot._make_plot(self, fig)
#    1336 color = self.color
#    1337 c_values = self._get_c_values(color, color_by_categorical, c_is_column)
# -> 1338 norm, cmap = self._get_norm_and_cmap(c_values, color_by_categorical)
#    1339 cb = self._get_colorbar(c_values, c_is_column)
#    1341 if self.legend:
#
# File c:\Python39\lib\site-packages\pandas\plotting\_matplotlib\core.py:1397, in ScatterPlot._get_norm_and_cmap(self, c_values, color_by_categorical)
#    1395 c = self.c
#    1396 if self.colormap is not None:
# -> 1397     cmap = mpl.colormaps.get_cmap(self.colormap)
#    1398 # cmap is only used if c_values are integers, otherwise UserWarning.
#    1399 # GH-53908: additionally call isinstance() because is_integer_dtype
#    1400 # returns True for "b" (meaning "blue" and not int8 in this context)
#    1401 elif not isinstance(c_values, str) and is_integer_dtype(c_values):
#    1402     # pandas uses colormap, matplotlib uses cmap.
#
# AttributeError: 'ColormapRegistry' object has no attribute 'get_cmap'

# %% [markdown]
# It is a bit annoying that there is a colorbar, as we know the origin is categorical.
#
# One way to avoid the colorbar is to loop over the categories and assign colors based on the category.
#
# See:
# https://stackoverflow.com/questions/26139423/plot-different-color-for-different-categorical-levels-using-matplotlib

# %%
# Replace variables to correspond to auto-mpg dataset
colors = {0: 'tab:blue', 1: 'tab:orange'}
fig, ax = plt.subplots()
for key, group in data.groupby(by='origin'):
    group.plot.scatter('mpg', 'weight', c=colors[key], label=key, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 5
#       3 fig, ax = plt.subplots()
#       4 for key, group in data.groupby(by='origin'):
# ----> 5     group.plot.scatter('mpg', 'weight', c=colors[key], label=key, ax=ax)
#
# KeyError: 2

# %% [markdown]
# ## Seaborn
# >Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# http://seaborn.pydata.org/index.html
#
# Seaborn is usually imported as `sns`

# %%
import seaborn as sns

# %% [markdown]
# Let's re-create the histograms with seaborn with the figure level `displot()` function.

# %%
# Replace variables to correspond to auto-mpg dataset
sns.displot(x='mpg', col='origin', data=data)

# %% [markdown]
# We can display the counts in the same plot, one on top of the other.

# %%
# Replace variables to correspond to auto-mpg dataset
sns.displot(x='mpg', hue='origin', data=data);

# %% [markdown]
# To have an idea of the split between origins, we can stack the counts, adding up to total.

# %%
# Replace variables to correspond to auto-mpg dataset
sns.displot(x='mpg', hue='origin', data=data, multiple='stack');

# %% [markdown]
# We can look at the differences with a boxplot too

# %%
# Replace variables to correspond to auto-mpg dataset
sns.boxplot(x='origin', y='mpg', data=data);

# %% [markdown]
# Let's re-create the scatter plot
#
# To make the legend show strings we will create an origin string column with origin_1, origin_2 and origin_3 strings rather than 1, 2 or 3.

# %%
# Replace variables to correspond to auto-mpg dataset
data['origin_str'] = data['origin'].replace([0, 1], ['female', 'male'])

# %%
# Replace variables to correspond to auto-mpg dataset
ax = sns.scatterplot(x='mpg', y='origin', data=data, hue='origin_str')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Replace variables to correspond to auto-mpg dataset
# ----> 2 ax = sns.scatterplot(x='mpg', y='origin', data=data, hue='origin_str')
#
# File c:\Python39\lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Python39\lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File c:\Python39\lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Python39\lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Python39\lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Python39\lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `origin_str` for `hue`. An entry with this name does not appear in `data`.

# %% [markdown]
# Adding a regression line helps with visualizing the relationship

# %%
# Replace variables to correspond to auto-mpg dataset
ax = sns.lmplot(x='mpg', y='origin', data=data, hue='origin')

# %% [markdown]
# Maybe there are other correlations in the data set. Pairplot is a great way to get an overview

# %%
# Replace variables to correspond to auto-mpg dataset
sns.pairplot(data, vars=['mpg', 'origin', 'chol', 'thalach'], hue='origin');

# %% [markdown]
# As an alternative, we can visualize the correlation matrix as a heatmap

# %%
# Replace variables to correspond to auto-mpg dataset
g = sns.heatmap(data[['mpg', 'trestbps', 'chol', 'thalach']].corr(method='spearman'), 
            annot=True)

# %% [markdown]
# If you need any help, check out the tutorials on the Seaborn website
